# %%
# Create a list of names
def generate_name(gender):
    syllables = ['o','i','e']
    female_names = ["Emma", "Ava", "Olivia", "Sophia", "Isabella", "Mia", "Emily", "Abigail", "Madison", "Elizabeth", "Charlotte", "Avery", "Sofia", "Aria", "Chloe", "Harper", "Ella", "Amelia", "Aubrey", "Addison", "Evelyn", "Natalie", "Grace", "Hannah", "Zoe", "Victoria", "Lillian", "Lily", "Brooklyn", "Leah", "Zoey", "Audrey", "Savannah", "Allison", "Samantha", "Aaliyah", "Kaylee", "Hailey", "Arianna", "Aurora", "Riley", "Ariana", "Peyton", "Makayla", "Layla", "Brooklynn", "Sarah", "Anna", "Piper", "Gianna", "Serena", "Brielle", "Jordyn", "Nora", "Reagan", "Jocelyn", "Hazel", "Stella", "Violet", "Claire", "Bella", "Molly", "Lucy", "Sadie", "Raelynn", "Lila", "Saylor", "Skylar", "Ellie", "Avery", "Aria", "Peyton", "Camila", "Payton", "Natalie", "Hailee", "Mila", "Ashlyn", "Ainsley", "Jordan", "Luna", "Jasmine", "Caroline", "Savannah", "Arianna", "Alessandra", "Mackenzie", "Lydia", "Melanie", "Avery", "Isabelle", "Julia", "Alaina", "Annabelle",'Adam', 'Ben', 'Charlie', 'Dave', 'Ethan', 'Frank', 'Gary', 'Henry', 'Isaac', 'Jack', 'Kevin', 'Liam', 'Matt', 'Nick', 'Oliver', 'Peter', 'Quinn', 'Ryan', 'Sam', 'Tom', 'Tyler', 'Victor', 'William', 'Xavier', 'Zach', 'Aaron', 'Brian', 'Carson', 'Dylan', 'Evan', 'Finn', 'Graham', 'Harrison', 'Isaac', 'Jordan', 'Kyle', 'Lucas', 'Max', 'Nathan', 'Owen', 'Parker', 'Quinn', 'Ryan', 'Sam', 'Taylor', 'Ulysses', 'Vincent', 'Wyatt', 'Xavier', 'Zachary', 'Aaron', 'Brandon', 'Christian', 'David', 'Edward', 'Frank', 'George', 'Henry', 'Isaac', 'James', 'Kevin', 'Liam', 'Michael', 'Nathan', 'Oliver', 'Patrick', 'Quinn', 'Robert', 'Sam', 'Thomas', 'Ulysses', 'Victor', 'William', 'Xavier', 'Zachary']
    male_names = ['Adam', 'Alex', 'Andrew', 'Ben', 'Brent', 'Brian', 'Chris', 'Dan', 'David', 'Ethan', 'Frank', 'Gary', 'Gavin', 'George', 'Jason', 'Jeremy', 'Jim', 'John', 'Jonathan', 'Josh', 'Justin', 'Keith', 'Kevin', 'Kyle', 'Lance', 'Larry', 'Mark', 'Matt', 'Michael', 'Mike', 'Nate', 'Nick', 'Paul', 'Phil', 'Rich', 'Robert', 'Sam', 'Scott', 'Sean', 'Seth', 'Steve', 'Tom', 'Tony', 'Tyler', 'Victor', 'Wade', 'Will', 'Zach', 'Aaron', 'Alan', 'Albert', 'Barry', 'Bill', 'Brad', 'Brett', 'Carl', 'Chad', 'Charles', 'Clayton', 'Curtis', 'Dale', 'Darrell', 'Darren', 'Dennis', 'Drew', 'Dustin', 'Edward', 'Eric', 'Evan', 'Gerald', 'Grant', 'Greg', 'Hank', 'Henry', 'Jack', 'Jacob', 'James', 'Jay', 'Jeff', 'Jeremy', 'Joe', 'Joel', 'John', 'Jordan', 'Jose', 'Joseph', 'Justin', 'Keith', 'Ken', 'Kevin', 'Kyle', 'Lance', 'Lee', 'Leonard', 'Lorenzo', 'Mark', 'Mason', 'Matthew', 'Maurice', 'Micheal', 'Mike', 'Nathan', 'Nigel', 'Patrick', 'Paul', 'Pete', 'Peter', 'Philip', 'Randall', 'Randy', 'Ray', 'Richard', 'Rick', 'Rob', 'Robert', 'Ron', 'Scott', 'Sean', 'Shawn', 'Steven', 'Tom', 'Trevor', 'Tyler', 'Vincent', 'Wade', 'Wayne', 'Will', 'William', 'Zach']
    # Modify an existing name by changing its spelling
    if gender == 'male':
        name = random.choice(male_names)
    else:
        name = random.choice(female_names)
        
    name = "".join([syllables[random.randint(0, len(syllables)-1)] if ch == "a" else ch for ch in name])

    # Add a syllable to the name
    name += syllables[random.randint(0, len(syllables)-1)]

    return name

# %%
import pandas as pd
import numpy as np
import random

# Create an empty dataframe
df = pd.DataFrame(columns=['name', 'age', 'gender', 'minutes_from_gym',
                           'purchase_frequency_items', 'average_purchase_amount_of_items',
                           'average_visits_per_month', 'membership_type',
                           'number_of_months_with_membership', 'number_of_months_with_gym','real_segment'])

# Generate random data for the dataframe
for i in range(1000):
    # Assign a segment based on age
    if i < 334:
        segment = 1
    elif i < 698:
        segment = 2
    else:
        segment = 3
    
    # Assign an age within a range for each segment, with a bit of deviation
    if segment == 1:
        #Assign an age
        age = round(random.randint(16, 30) + random.uniform(-3, 3))
        
        # Assign a random gender
        gender = random.choices(['male', 'female'], weights=[0.5, 0.5])[0]
        
        # Assign a random distance from the gym
        minutes_from_gym = round(random.uniform(30, 45), 2)
        
        # Assign a random purchase frequency
        purchase_frequency_items = random.randint(0, 2)

        # Assign a random average purchase amount
        average_purchase_amount_of_items = round(random.uniform(2, 5), 2)

        # Assign a random average number of visits per month
        average_visits_per_month = random.randint(0, 6)

        # Assign a random membership type
        membership_type = random.choices(['monthly', '3 month','yearly'], weights=[0.9, 0.05, 0.05 ])[0]

        # Assign a random number of months with membership
        number_of_months_with_membership = random.randint(0, 3)

        # Assign a random number of months with gym
        number_of_months_with_gym = random.randint(0, 3)
        
        
    elif segment == 2:
        #Assign an age
        age = round(random.randint(20, 36) + random.uniform(-3, 3))
        
        # Assign a random gender
        gender = random.choices(['male', 'female'], weights=[0.6, 0.4])[0]
        
        # Assign a random distance from the gym
        minutes_from_gym = round(random.uniform(20, 30), 2)
        
        # Assign a random purchase frequency
        purchase_frequency_items = random.randint(2, 4)

        # Assign a random average purchase amount
        average_purchase_amount_of_items = round(random.uniform(4, 20), 2)

        # Assign a random average number of visits per month
        average_visits_per_month = random.randint(6, 8)

        # Assign a random membership type
        membership_type = random.choices(['monthly', '3 month','yearly'], weights=[0.5, 0.4, 0.1 ])[0]

        # Assign a random number of months with membership
        number_of_months_with_membership = random.randint(2, 5)

        # Assign a random number of months with gym
        number_of_months_with_gym = random.randint(2, 5)
        
        
    elif segment == 3:
        #Assign an age
        age = round(random.randint(26, 48) + random.uniform(-3, 3))
        
        # Assign a random gender
        gender = random.choices(['male', 'female'], weights=[0.7, 0.3])[0]
        
        # Assign a random distance from the gym
        minutes_from_gym = round(random.uniform(5, 20), 2)
        
        # Assign a random purchase frequency
        purchase_frequency_items = random.randint(4, 8)

        # Assign a random average purchase amount
        average_purchase_amount_of_items = round(random.uniform(10, 20), 2)

        # Assign a random average number of visits per month
        average_visits_per_month = random.randint(7, 14)

        # Assign a random membership type
        membership_type = random.choices(['monthly', '3 month','yearly'], weights=[0.1, 0.3, 0.6 ])[0]

        # Assign a random number of months with membership
        number_of_months_with_membership = random.randint(7, 24)

        # Assign a random number of months with gym
        number_of_months_with_gym = random.randint(7, 24)
    
    # Assign a random name
    name = generate_name(gender)

    # Append the new row to the DataFrame
    df.loc[len(df)] = [name, age, gender, minutes_from_gym, purchase_frequency_items, average_purchase_amount_of_items, average_visits_per_month, membership_type, number_of_months_with_membership, number_of_months_with_gym,segment]
    
df.head()
